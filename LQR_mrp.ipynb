# %%
ENV["JULIA_NUM_PRECOMPILE_TASKS"] = "1"

import Pkg
Pkg.activate(@__DIR__)
Pkg.update()  # Update project packages
Pkg.resolve()
Pkg.instantiate()

# Load packages in groups to isolate failures
using Rotations, LinearAlgebra, RigidBodyDynamics, LightXML
using GeometryBasics, CoordinateTransformations, StaticArrays
using Ipopt, ECOS, JLD2, Random, Test, Printf
using MeshCatMechanisms
import MeshCat as mc
import MathOptInterface as MOI
import ForwardDiff as FD 
import Convex as cvx 
using Plots  # Load last due to heavy dependencies
# Out:
#   Activating project at `~/tiltrotor_control`
#   Installing known registries into `~/.julia`
#     Updating registry at `~/.julia/registries/General.toml`
#    Installed JpegTurbo_jll ──────────────── v3.1.1+0
#    Installed libdecor_jll ───────────────── v0.2.2+0
#    Installed x265_jll ───────────────────── v3.5.0+0
#    Installed libfdk_aac_jll ─────────────── v2.0.3+0
#    Installed Libmount_jll ───────────────── v2.41.0+0
#    Installed GR_jll ─────────────────────── v0.73.13+0
#    Installed OffsetArrays ───────────────── v1.16.0
#    Installed MutableArithmetics ─────────── v1.6.4
#    Installed LERC_jll ───────────────────── v4.0.1+0
#    Installed Xorg_xkbcomp_jll ───────────── v1.4.6+1
#    Installed Opus_jll ───────────────────── v1.3.3+0
#    Installed TypeSortedCollections ──────── v1.1.0
#    Installed LoggingExtras ──────────────── v1.1.0
#    Installed RelocatableFolders ─────────── v1.0.1
#    Installed Preferences ────────────────── v1.4.3
#    Installed Unitful ────────────────────── v1.22.0
#    Installed ColorSchemes ───────────────── v3.29.0
#    Installed Measures ───────────────────── v0.3.2
#    Installed Contour ────────────────────── v0.6.3
#    Installed ConcurrentUtilities ────────── v2.5.0
#    Installed Pidfile ────────────────────── v1.3.0
#    Installed EarCut_jll ─────────────────── v2.2.4+0
#    Installed StaticArrays ───────────────── v1.9.13
#    Installed Xorg_xcb_util_image_jll ────── v0.4.0+1
#    Installed Grisu ──────────────────────── v1.0.2
#    Installed Xorg_xcb_util_wm_jll ───────── v0.4.1+1
#    Installed RecipesPipeline ────────────── v0.6.12
#    Installed PlotUtils ──────────────────── v1.4.3
#    Installed OpenSSL ────────────────────── v1.4.3
#    Installed FileIO ─────────────────────── v1.17.0
#    Installed GR ─────────────────────────── v0.73.13
#    Installed CEnum ──────────────────────── v0.5.0
#    Installed MeshCat ────────────────────── v0.16.2
#    Installed Xorg_libSM_jll ─────────────── v1.2.6+0
#    Installed AMD ────────────────────────── v0.5.3
#    Installed HTTP ───────────────────────── v1.10.16
#    Installed Cairo_jll ──────────────────── v1.18.4+0
#    Installed Xorg_xcb_util_jll ──────────── v0.4.0+1
#    Installed OpenBLAS32_jll ─────────────── v0.3.17+0
#    Installed Convex ─────────────────────── v0.16.4
#    Installed ECOS ───────────────────────── v1.1.3
#    Installed Fontconfig_jll ─────────────── v2.16.0+0
#    Installed Xorg_libXinerama_jll ───────── v1.1.5+0
#    Installed Xorg_libxkbfile_jll ────────── v1.1.2+1
#    Installed EpollShim_jll ──────────────── v0.0.20230411+1
#    Installed Xorg_libXau_jll ────────────── v1.0.13+0
#    Installed Missings ───────────────────── v1.2.0
#    Installed WebIO ──────────────────────── v0.8.21
#    Installed FFMPEG ─────────────────────── v0.4.2
#    Installed JLD2 ───────────────────────── v0.5.12
#    Installed IrrationalConstants ────────── v0.2.4
#    Installed RealDot ────────────────────── v0.1.0
#    Installed Showoff ────────────────────── v1.0.3
#    Installed RigidBodyDynamics ──────────── v2.5.0
#    Installed MathOptInterface ───────────── v1.39.0
#    Installed Pango_jll ──────────────────── v1.56.1+0
#    Installed PtrArrays ──────────────────── v1.3.0
#    Installed JSON ───────────────────────── v0.21.4
#    Installed MUMPS_seq_jll ──────────────── v5.4.1+0
#    Installed BenchmarkTools ─────────────── v1.6.0
#    Installed SpecialFunctions ───────────── v2.5.1
#    Installed Xorg_xcb_util_keysyms_jll ──── v0.4.0+1
#    Installed FiniteDiff ─────────────────── v2.22.0
#    Installed xkbcommon_jll ──────────────── v1.4.1+2
#    Installed Bzip2_jll ──────────────────── v1.0.9+0
#    Installed CodecBzip2 ─────────────────── v0.8.5
#    Installed SimpleBufferStream ─────────── v1.2.0
#    Installed XZ_jll ─────────────────────── v5.8.1+0
#    Installed HarfBuzz_jll ───────────────── v8.5.0+0
#    Installed LZO_jll ────────────────────── v2.10.3+0
#    Installed StaticArraysCore ───────────── v1.4.3
#    Installed NaNMath ────────────────────── v1.0.3
#    Installed PlotThemes ─────────────────── v3.3.0
#    Installed MsgPack ────────────────────── v1.2.1
#    Installed JuMP ───────────────────────── v1.25.0
#    Installed Ipopt_jll ──────────────────── v300.1400.400+0
#    Installed FriBidi_jll ────────────────── v1.0.17+0
#    Installed fzf_jll ────────────────────── v0.56.3+0
#    Installed MbedTLS ────────────────────── v1.1.9
#    Installed UnicodeFun ─────────────────── v0.4.1
#    Installed UnsafeArrays ───────────────── v1.0.7
#    Installed TranscodingStreams ─────────── v0.11.3
#    Installed AssetRegistry ──────────────── v0.1.0
#    Installed GLFW_jll ───────────────────── v3.4.0+2
#    Installed x264_jll ───────────────────── v2021.5.5+0
#    Installed Ratios ─────────────────────── v0.4.5
#    Installed JLFzf ──────────────────────── v0.1.10
#    Installed CommonSubexpressions ───────── v0.3.1
#    Installed DataStructures ─────────────── v0.18.22
#    Installed StatsAPI ───────────────────── v1.7.0
#    Installed METIS_jll ──────────────────── v5.1.3+0
#    Installed CodecZlib ──────────────────── v0.7.8
#    Installed Xorg_libxcb_jll ────────────── v1.17.1+0
#    Installed FreeType2_jll ──────────────── v2.13.4+0
#    Installed Compat ─────────────────────── v4.16.0
#    Installed StatsBase ──────────────────── v0.34.4
#    Installed Colors ─────────────────────── v0.12.11
#    Installed libpng_jll ─────────────────── v1.6.47+0
#    Installed mtdev_jll ──────────────────── v1.1.6+0
#    Installed StructTypes ────────────────── v1.11.0
#    Installed libaom_jll ─────────────────── v3.11.0+0
#    Installed Scratch ────────────────────── v1.2.1
#    Installed ExceptionUnwrapping ────────── v0.1.11
#    Installed WebSockets ─────────────────── v1.6.0
#    Installed gperf_jll ──────────────────── v3.1.1+1
#    Installed Dbus_jll ───────────────────── v1.16.2+0
#    Installed DiffRules ──────────────────── v1.15.1
#    Installed eudev_jll ──────────────────── v3.2.9+0
#    Installed Xorg_libXext_jll ───────────── v1.3.6+3
#    Installed Plots ──────────────────────── v1.40.12
#    Installed ECOS_jll ───────────────────── v200.0.800+0
#    Installed JSON3 ──────────────────────── v1.14.2
#    Installed ColorTypes ─────────────────── v0.11.5
#    Installed TensorCore ─────────────────── v0.1.1
#    Installed TableTraits ────────────────── v1.0.1
#    Installed Xorg_xcb_util_cursor_jll ───── v0.1.4+0
#    Installed Expat_jll ──────────────────── v2.6.5+0
#    Installed DiffResults ────────────────── v1.1.0
#    Installed Setfield ───────────────────── v1.1.2
#    Installed Libtiff_jll ────────────────── v4.7.1+0
#    Installed JLLWrappers ────────────────── v1.7.0
#    Installed Format ─────────────────────── v1.3.7
#    Installed ColorVectorSpace ───────────── v0.10.0
#    Installed Extents ────────────────────── v0.1.4
#    Installed DataValueInterfaces ────────── v1.0.0
#    Installed Libffi_jll ─────────────────── v3.2.2+2
#    Installed OrderedCollections ─────────── v1.8.0
#    Installed AbstractTrees ──────────────── v0.4.5
#    Installed Parsers ────────────────────── v2.8.2
#    Installed Zstd_jll ───────────────────── v1.5.7+1
#    Installed Xorg_libXrender_jll ────────── v0.9.11+1
#    Installed libevdev_jll ───────────────── v1.11.0+0
#    Installed libinput_jll ───────────────── v1.18.0+0
#    Installed CoordinateTransformations ──── v0.6.3
#    Installed Xorg_libXi_jll ─────────────── v1.8.2+0
#    Installed Vulkan_Loader_jll ──────────── v1.3.243+0
#    Installed ConstructionBase ───────────── v1.5.8
#    Installed ArrayInterface ─────────────── v7.5.1
#    Installed Qt6ShaderTools_jll ─────────── v6.7.1+1
#    Installed Ogg_jll ────────────────────── v1.3.5+1
#    Installed Qt6Declarative_jll ─────────── v6.7.1+2
#    Installed Reexport ───────────────────── v1.2.2
#    Installed ChainRulesCore ─────────────── v1.25.1
#    Installed Quaternions ────────────────── v0.7.6
#    Installed Knockout ───────────────────── v0.2.6
#    Installed AliasTables ────────────────── v1.1.3
#    Installed LogExpFunctions ────────────── v0.3.28
#    Installed MacroTools ─────────────────── v0.5.15
#    Installed Rotations ──────────────────── v1.7.1
#    Installed Interpolations ─────────────── v0.14.7
#    Installed ASL_jll ────────────────────── v0.1.3+0
#    Installed OpenSpecFun_jll ────────────── v0.5.6+0
#    Installed UnPack ─────────────────────── v1.0.2
#    Installed GeoFormatTypes ─────────────── v0.4.4
#    Installed MechanismGeometries ────────── v0.7.1
#    Installed InverseFunctions ───────────── v0.1.17
#    Installed Libuuid_jll ────────────────── v2.41.0+0
#    Installed Xorg_libXcursor_jll ────────── v1.2.3+0
#    Installed DocStringExtensions ────────── v0.9.4
#    Installed Wayland_protocols_jll ──────── v1.36.0+0
#    Installed Xorg_xcb_util_renderutil_jll ─ v0.3.9+1
#    Installed Xorg_libICE_jll ────────────── v1.1.2+0
#    Installed StableRNGs ─────────────────── v1.0.2
#    Installed Adapt ──────────────────────── v3.7.2
#    Installed Widgets ────────────────────── v0.6.7
#    Installed Graphite2_jll ──────────────── v1.3.15+0
#    Installed Pixman_jll ─────────────────── v0.44.2+0
#    Installed XML2_jll ───────────────────── v2.13.6+1
#    Installed LoopThrottle ───────────────── v0.1.0
#    Installed Latexify ───────────────────── v0.16.7
#    Installed JSExpr ─────────────────────── v0.5.4
#    Installed GPUArraysCore ──────────────── v0.1.5
#    Installed libass_jll ─────────────────── v0.15.2+0
#    Installed Wayland_jll ────────────────── v1.21.0+2
#    Installed Xorg_xtrans_jll ────────────── v1.6.0+0
#    Installed OpenSSL_jll ────────────────── v3.0.16+0
#    Installed IterTools ──────────────────── v1.10.0
#    Installed BitFlags ───────────────────── v0.1.9
#    Installed Gettext_jll ────────────────── v0.21.0+0
#    Installed FFMPEG_jll ─────────────────── v4.4.4+1
#    Installed FunctionalCollections ──────── v0.5.0
#    Installed Tables ─────────────────────── v1.12.0
#    Installed Xorg_xkeyboard_config_jll ──── v2.39.0+0
#    Installed Cassette ───────────────────── v0.3.14
#    Installed DataAPI ────────────────────── v1.16.0
#    Installed LLVMOpenMP_jll ─────────────── v18.1.7+0
#    Installed FixedPointNumbers ──────────── v0.8.5
#    Installed Xorg_libXrandr_jll ─────────── v1.5.4+0
#    Installed RecipesBase ────────────────── v1.3.4
#    Installed Ipopt ──────────────────────── v1.8.0
#    Installed Xorg_libXfixes_jll ─────────── v6.0.0+0
#    Installed Qt6Wayland_jll ─────────────── v6.7.1+1
#    Installed GeometryBasics ─────────────── v0.4.11
#    Installed PrecompileTools ────────────── v1.2.1
#    Installed IteratorInterfaceExtensions ── v1.0.0
#    Installed Libiconv_jll ───────────────── v1.18.0+0
#    Installed Qt6Base_jll ────────────────── v6.7.1+1
#    Installed URIs ───────────────────────── v1.5.2
#    Installed LAME_jll ───────────────────── v3.100.2+0
#    Installed MeshCatMechanisms ──────────── v0.9.0
#    Installed InteractBase ───────────────── v0.10.10
#    Installed Glib_jll ───────────────────── v2.82.4+0
#    Installed LaTeXStrings ───────────────── v1.4.0
#    Installed libvorbis_jll ──────────────── v1.3.7+2
#    Installed LDLFactorizations ──────────── v0.10.1
#    Installed CSSUtil ────────────────────── v0.1.1
#    Installed ForwardDiff ────────────────── v0.10.38
#    Installed StructArrays ───────────────── v0.6.18
#    Installed AxisAlgorithms ─────────────── v1.0.1
#    Installed Polyhedra ──────────────────── v0.7.8
#    Installed Requires ───────────────────── v1.3.1
#    Installed Xorg_libXdmcp_jll ──────────── v1.1.6+0
#    Installed Libglvnd_jll ───────────────── v1.7.0+0
#    Installed GeoInterface ───────────────── v1.4.1
#    Installed Parameters ─────────────────── v0.12.3
#    Installed UnitfulLatexify ────────────── v1.6.4
#    Installed LightXML ───────────────────── v0.9.1
#    Installed Xorg_libX11_jll ────────────── v1.8.6+3
#    Installed Unzip ──────────────────────── v0.2.0
#    Installed Observables ────────────────── v0.5.5
#    Installed SortingAlgorithms ──────────── v1.2.1
#    Installed GenericLinearAlgebra ───────── v0.3.15
#    Installed WoodburyMatrices ───────────── v0.5.6
#    Installed DifferentiableCollisions ───── v0.1.5
#    Installed ChangesOfVariables ─────────── v0.1.9
# ┌ Warning: The active manifest file at `/home/hariharan/tiltrotor_control/Manifest.toml` has an old format that is being maintained.
# │ To update to the new format, which is supported by Julia versions ≥ 1.6.2, run `Pkg.upgrade_manifest()` which will upgrade the format without re-resolving.
# │ To then record the julia version re-resolve with `Pkg.resolve()` and if there are resolve conflicts consider `Pkg.update()`.
# └ @ Pkg.Types /cache/build/default-amdci4-2/julialang/julia-release-1-dot-8/usr/share/julia/stdlib/v1.8/Pkg/src/manifest.jl:287
#     Updating `~/tiltrotor_control/Project.toml`
# ⌅ [150eb455] ↓ CoordinateTransformations v0.6.4 ⇒ v0.6.3
# ⌅ [6a86dc24] ↓ FiniteDiff v2.27.0 ⇒ v2.22.0
#   [37e2e46d] ~ LinearAlgebra v1.11.0 ⇒
#     Updating `~/tiltrotor_control/Manifest.toml`
# ⌅ [79e6a3ab] ↓ Adapt v4.3.0 ⇒ v3.7.2
# ⌅ [4fba245c] ↓ ArrayInterface v7.18.0 ⇒ v7.5.1
#   [9e997f8a] + ChangesOfVariables v0.1.9
# ⌅ [150eb455] ↓ CoordinateTransformations v0.6.4 ⇒ v0.6.3
# ⌅ [411431e0] ↓ Extents v0.1.5 ⇒ v0.1.4
# ⌅ [6a86dc24] ↓ FiniteDiff v2.27.0 ⇒ v2.22.0
# ⌅ [46192b85] + GPUArraysCore v0.1.5
# ⌅ [a98d9a8b] ↑ Interpolations v0.14.0 ⇒ v0.14.7
#   [3587e190] + InverseFunctions v0.1.17
# ⌅ [2ab3a3ac] ↓ LogExpFunctions v0.3.29 ⇒ v0.3.28
# ⌅ [77ba4419] ↓ NaNMath v1.1.3 ⇒ v1.0.3
#   [69de0a69] ↑ Parsers v2.8.1 ⇒ v2.8.2
# ⌅ [09ab397b] ↓ StructArrays v0.6.21 ⇒ v0.6.18
#   [f489334b] - StyledStrings v1.11.0
#   [e33a78d0] - Hwloc_jll v2.12.0+0
# ⌅ [9cc047cb] ↓ Ipopt_jll v300.1400.1700+0 ⇒ v300.1400.400+0
# ⌅ [d7ed1dd3] ↓ MUMPS_seq_jll v500.700.301+0 ⇒ v5.4.1+0
# ⌅ [656ef2d0] ↓ OpenBLAS32_jll v0.3.29+0 ⇒ v0.3.17+0
#   [319450e9] - SPRAL_jll v2024.5.8+0
#   [0dad84c5] ↓ ArgTools v1.1.2 ⇒ v1.1.1
#   [56f22d72] ~ Artifacts v1.11.0 ⇒
#   [2a0f44e3] ~ Base64 v1.11.0 ⇒
#   [ade2ca70] ~ Dates v1.11.0 ⇒
#   [8bb1440f] ~ DelimitedFiles v1.9.1 ⇒
#   [8ba89e20] ~ Distributed v1.11.0 ⇒
#   [7b1f6079] ~ FileWatching v1.11.0 ⇒
#   [9fa8497b] ~ Future v1.11.0 ⇒
#   [b77e0a4c] ~ InteractiveUtils v1.11.0 ⇒
#   [b27032c2] ↓ LibCURL v0.6.4 ⇒ v0.6.3
#   [76f85450] ~ LibGit2 v1.11.0 ⇒
#   [8f399da3] ~ Libdl v1.11.0 ⇒
#   [37e2e46d] ~ LinearAlgebra v1.11.0 ⇒
#   [56ddb016] ~ Logging v1.11.0 ⇒
#   [d6f4376e] ~ Markdown v1.11.0 ⇒
#   [a63ad114] ~ Mmap v1.11.0 ⇒
#   [44cfe95a] ↓ Pkg v1.11.0 ⇒ v1.8.0
#   [de0858da] ~ Printf v1.11.0 ⇒
#   [9abbd945] ~ Profile v1.11.0 ⇒
#   [3fa0cd96] ~ REPL v1.11.0 ⇒
#   [9a3f8284] ~ Random v1.11.0 ⇒
#   [9e88b42a] ~ Serialization v1.11.0 ⇒
#   [1a1011a3] ~ SharedArrays v1.11.0 ⇒
#   [6462fe0b] ~ Sockets v1.11.0 ⇒
#   [2f01184e] ~ SparseArrays v1.11.0 ⇒
#   [10745b16] ~ Statistics v1.11.1 ⇒
#   [4607b0f0] + SuiteSparse
#   [fa267f1f] ↓ TOML v1.0.3 ⇒ v1.0.0
#   [a4e569a6] ↑ Tar v1.10.0 ⇒ v1.10.1
#   [8dfed614] ~ Test v1.11.0 ⇒
#   [cf7118a7] ~ UUIDs v1.11.0 ⇒
#   [4ec0a83e] ~ Unicode v1.11.0 ⇒
#   [e66e0078] ↓ CompilerSupportLibraries_jll v1.1.1+0 ⇒ v1.0.1+0
#   [deac9b47] ↓ LibCURL_jll v8.6.0+0 ⇒ v7.84.0+0
#   [e37daf67] - LibGit2_jll v1.7.2+0
#   [29816b5a] ↓ LibSSH2_jll v1.11.0+1 ⇒ v1.10.2+0
#   [c8ffd9c3] ↓ MbedTLS_jll v2.28.6+0 ⇒ v2.28.0+0
#   [14a3606d] ↓ MozillaCACerts_jll v2023.12.12 ⇒ v2022.2.1
#   [4536629a] ↓ OpenBLAS_jll v0.3.27+1 ⇒ v0.3.20+0
#   [05823500] ↓ OpenLibm_jll v0.8.5+0 ⇒ v0.8.1+0
#   [efcefdf7] ↓ PCRE2_jll v10.42.0+1 ⇒ v10.40.0+0
#   [bea87d4a] ↓ SuiteSparse_jll v7.7.0+0 ⇒ v5.10.1+0
#   [83775a58] ↓ Zlib_jll v1.2.13+1 ⇒ v1.2.12+3
#   [8e850b90] ↓ libblastrampoline_jll v5.11.0+0 ⇒ v5.1.1+0
#   [8e850ede] ↓ nghttp2_jll v1.59.0+0 ⇒ v1.48.0+0
#   [3f19e933] ↓ p7zip_jll v17.4.0+2 ⇒ v17.4.0+0
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
#     Building WebIO ────────────→ `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/0eef0765186f7452e52236fa42ca8c9b3c11c6e3/build.log`
#     Building Knockout ─────────→ `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/91835de56d816864f1c38fb5e3fad6eb1e741271/build.log`
#     Building RigidBodyDynamics → `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/212ee0a4c2ca1b734dfd439d14c8a77fa4d14a39/build.log`
#     Building InteractBase ─────→ `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/aa5daeff326db0a9126a225b58ca04ae12f57259/build.log`
# ┌ Warning: The active manifest file is an older format with no julia version entry. Dependencies may have been resolved with a different julia version.
# └ @ nothing /home/hariharan/tiltrotor_control/Manifest.toml:0
# Precompiling project...
#   ✓ Cassette
#   ✓ StructTypes
#   ✓ LaTeXStrings
#   ✓ IteratorInterfaceExtensions
#   ✓ TensorCore
#   ✓ GeoFormatTypes
#   ✓ StatsAPI
#   ✓ Contour
#   ✓ CEnum
#   ✓ ConcurrentUtilities
#   ✓ TypeSortedCollections
#   ✓ UnsafeArrays
#   ✓ MutableArithmetics
#   ✓ Format
#   ✓ FixedPointNumbers
#   ✓ UnPack
#   ✓ OpenLibm_jll
#   ✓ Measures
#   ✓ InverseFunctions
#   ✓ LoopThrottle
#   ✓ WoodburyMatrices
#   ✓ CompilerSupportLibraries_jll
#   ✓ IterTools
#   ✓ MacroTools
#   ✓ Grisu
#   ✓ Compat
#   ✓ OrderedCollections
#   ✓ Observables
#   ✓ Requires
#   ✓ DataValueInterfaces
#   ✓ RealDot
#   ✓ StableRNGs
#   ✓ Unzip
#   ✓ Reexport
#   ✓ MbedTLS_jll
#   ✓ Zlib_jll
#   ✓ DocStringExtensions
#   ✓ Pidfile
#   ✓ AbstractTrees
#   ✓ IrrationalConstants
#   ✓ URIs
#   ✓ MsgPack
#   ✓ SimpleBufferStream
#   ✓ ExceptionUnwrapping
#   ✓ Extents
#   ✓ PtrArrays
#   ✓ UnicodeFun
#   ✓ PCRE2_jll
#   ✓ TranscodingStreams
#   ✓ ConstructionBase
#   ✓ DataAPI
#   ✓ BitFlags
#   ✓ Scratch
#   ✓ LoggingExtras
#   ✓ FunctionalCollections
#   ✓ StaticArraysCore
#   ✓ JLLWrappers
#   ✓ RecipesBase
#   ✓ JSON3
#   ✓ TableTraits
#   ✓ ColorTypes
#   ✓ NaNMath
#   ✓ ChangesOfVariables
#   ✓ AxisAlgorithms
#   ✓ OpenBLAS_jll
#   ✓ CommonSubexpressions
#   ✓ Showoff
#   ✓ ChainRulesCore
#   ✓ BenchmarkTools
#   ✓ DataStructures
#   ✓ Parameters
#   ✓ Ratios
#   ✓ Adapt
#   ✓ FileIO
#   ✓ Latexify
#   ✓ Quaternions
#   ✓ MbedTLS
#   ✓ LibSSH2_jll
#   ✓ AssetRegistry
#   ✓ AliasTables
#   ✓ CodecZlib
#   ✓ Unitful
#   ✓ GeoInterface
#   ✓ Missings
#   ✓ RelocatableFolders
#   ✓ DiffResults
#   ✓ StaticArrays
#   ✓ Setfield
#   ✓ OpenSSL_jll
#   ✓ Graphite2_jll
#   ✓ Libmount_jll
#   ✓ EpollShim_jll
#   ✓ LLVMOpenMP_jll
#   ✓ Bzip2_jll
#   ✓ OpenBLAS32_jll
#   ✓ METIS_jll
#   ✓ Xorg_libICE_jll
#   ✓ Xorg_libXau_jll
#   ✓ libpng_jll
#   ✓ libfdk_aac_jll
#   ✓ ASL_jll
#   ✓ LAME_jll
#   ✓ LERC_jll
#   ✓ fzf_jll
#   ✓ EarCut_jll
#   ✓ JpegTurbo_jll
#   ✓ XZ_jll
#   ✓ Ogg_jll
#   ✓ mtdev_jll
#   ✓ gperf_jll
#   ✓ Xorg_libXdmcp_jll
#   ✓ x265_jll
#   ✓ x264_jll
#   ✓ libaom_jll
#   ✓ Zstd_jll
#   ✓ Expat_jll
#   ✓ LZO_jll
#   ✓ Opus_jll
#   ✓ Xorg_xtrans_jll
#   ✓ libevdev_jll
#   ✓ ECOS_jll
#   ✓ Libiconv_jll
#   ✓ Libffi_jll
#   ✓ Wayland_protocols_jll
#   ✓ OpenSpecFun_jll
#   ✓ Libuuid_jll
#   ✓ FriBidi_jll
#   ✓ Tables
#   ✓ ColorVectorSpace
#   ✓ Colors
#   ✓ libblastrampoline_jll
#   ✓ LogExpFunctions
#   ✓ SortingAlgorithms
#   ✓ OffsetArrays
#   ✓ GPUArraysCore
#   ✓ ArrayInterface
#   ✓ JLD2
#   ✓ UnitfulLatexify
#   ✓ Rotations
#   ✓ CoordinateTransformations
#   ✓ OpenSSL
#   ✓ Pixman_jll
#   ✓ CodecBzip2
#   ✓ FreeType2_jll
#   ✓ MUMPS_seq_jll
#   ✓ Xorg_libSM_jll
#   ✓ JLFzf
#   ✓ libvorbis_jll
#   ✓ eudev_jll
#   ✓ Xorg_libxcb_jll
#   ✓ Libtiff_jll
#   ✓ Dbus_jll
#   ✓ XML2_jll
#   ✓ Widgets
#   ✓ ColorSchemes
#   ✓ GenericLinearAlgebra
#   ✓ SuiteSparse_jll
#   ✓ SpecialFunctions
#   ✓ StatsBase
#   ✓ Interpolations
#   ✓ StructArrays
#   ✓ FiniteDiff
#   ✓ HTTP
#   ✓ Fontconfig_jll
#   ✓ Ipopt_jll
#   ✓ libinput_jll
#   ✓ Xorg_xcb_util_jll
#   ✓ Xorg_libX11_jll
#   ✓ LightXML
#   ✓ Gettext_jll
#   ✓ Wayland_jll
#   ✓ PlotUtils
#   ✓ AMD
#   ✓ DiffRules
#   ✓ GeometryBasics
#   ✓ WebSockets
#   ✓ Xorg_xcb_util_image_jll
#   ✓ Xorg_xcb_util_keysyms_jll
#   ✓ Xorg_xcb_util_renderutil_jll
#   ✓ Xorg_xcb_util_wm_jll
#   ✓ Xorg_libXrender_jll
#   ✓ Xorg_libXext_jll
#   ✓ Xorg_libXfixes_jll
#   ✓ Xorg_libxkbfile_jll
#   ✓ RigidBodyDynamics
#   ✓ Glib_jll
#   ✓ PlotThemes
#   ✓ RecipesPipeline
#   ✓ LDLFactorizations
#   ✓ ForwardDiff
#   ✓ WebIO
#   ✓ Xorg_xcb_util_cursor_jll
#   ✓ Libglvnd_jll
#   ✓ Xorg_libXinerama_jll
#   ✓ Xorg_libXrandr_jll
#   ✓ Xorg_libXcursor_jll
#   ✓ Xorg_libXi_jll
#   ✓ Xorg_xkbcomp_jll
#   ✓ MechanismGeometries
#   ✓ Cairo_jll
#   ✓ MathOptInterface
#   ✓ JSExpr
#   ✓ CSSUtil
#   ✓ Xorg_xkeyboard_config_jll
#   ✓ HarfBuzz_jll
#   ✓ JuMP
#   ✓ Convex
#   ✓ ECOS
#   ✓ Ipopt
#   ✓ Knockout
#   ✓ xkbcommon_jll
#   ✓ libass_jll
#   ✓ Pango_jll
#   ✓ Polyhedra
#   ✓ InteractBase
#   ✓ Vulkan_Loader_jll
#   ✓ FFMPEG_jll
#   ✓ libdecor_jll
#   ✓ Qt6Base_jll
#   ✓ FFMPEG
#   ✓ GLFW_jll
#   ✓ Qt6ShaderTools_jll
#   ✓ MeshCat
#   ✓ GR_jll
#   ✓ Qt6Declarative_jll
#   ✓ DifferentiableCollisions
#   ✓ MeshCatMechanisms
#   ✓ Qt6Wayland_jll
#   ✓ GR
#   ✓ Plots
#   230 dependencies successfully precompiled in 246 seconds. 4 already precompiled.
# ┌ Info: We haven't cleaned this depot up for a bit, running Pkg.gc()...
# └ @ Pkg /cache/build/default-amdci4-2/julialang/julia-release-1-dot-8/usr/share/julia/stdlib/v1.8/Pkg/src/Pkg.jl:719
#       Active manifest files: 2 found
#       Active artifact files: 89 found
#       Active scratchspaces: 4 found
#      Deleted no artifacts, repos, packages or scratchspaces
#   No Changes to `~/tiltrotor_control/Project.toml`
#   No Changes to `~/tiltrotor_control/Manifest.toml`

# %%
include(joinpath(@__DIR__, "utils", "tiltrotor.jl"))

function discrete_dynamics(params::NamedTuple, x::Vector, u, k)
    # discrete dynamics
    # x - state 
    # u - control 
    # k - index of trajectory 
    # dt comes from params.model.dt 
    return rk4(params.model, tiltrotor_dynamics_mrp, x, u, params.model.dt)
end
# Out:
# discrete_dynamics (generic function with 1 method)

# %% [markdown]
# ## iLQR for Tiltrotor
#
# iLQR is used to solve optimal control problems of the following form:
# $$ \begin{align} \min_{x_{1:N},u_{1:N-1}} \quad & \bigg[ \sum_{i=1}^{N-1} \ell(x_i,u_i)\bigg] + \ell_N(x_N)\\
#  \text{st} \quad & x_1 = x_{{IC}} \\
#  & x_{k+1} = f(x_k, u_k) \quad \text{for } i = 1,2,\ldots,N-1 \\
#  \end{align}$$
#  where $x_{IC}$ is the inital condition, $x_{k+1} = f(x_k, u_k)$ is the discrete dynamics function, $\ell(x_i,u_i)$ is the stage cost, and $\ell_N(x_N)$ is the terminal cost.  Since this optimization problem can be non-convex, there is no guarantee of convergence to a global optimum, or even convergene rates to a local optimum, but in practice we will see that it can work very well.
#
# For this problem, we are going to use a simple cost function consisting of the following stage cost:
#
# $$ \ell(x_i,u_i) = \frac{1}{2} (x_i - x_{ref,i})^TQ(x_i - x_{ref,i}) + \frac{1}{2}(u_i - u_{ref,i})^TR(u_i - u_{ref,i}) $$
#
# And the following terminal cost:
#
# $$ \ell_N(x_N) = \frac{1}{2}(x_N - x_{ref,N})^TQ_f(x_N - x_{ref,N}) $$
#
# This is how we will encourange our tiltrotor to track a reference trajectory $x_{ref}$. We will consider iLQR to have converged when $\Delta J < \text{atol}$ as calculated during the backwards pass.

# %%
function stage_cost(p::NamedTuple,x::Vector,u::Vector,k::Int)
    return 0.5*(x-p.Xref[k])'*p.Q*(x-p.Xref[k]) + 0.5*(u-p.Uref[k])'*p.R*(u-p.Uref[k])
end

function term_cost(p::NamedTuple,x)
    return 0.5*(x-p.Xref[p.N])'*p.Qf*(x-p.Xref[p.N])
end

function stage_cost_expansion(p::NamedTuple, x::Vector, u::Vector, k::Int)
    return FD.hessian(x->stage_cost(p,x,u,k),x), FD.gradient(x->stage_cost(p,x,u,k),x), FD.hessian(u->stage_cost(p,x,u,k),u), FD.gradient(u->stage_cost(p,x,u,k),u)
end

function term_cost_expansion(p::NamedTuple, x::Vector)
    return FD.hessian(x->term_cost(p,x),x), FD.gradient(x->term_cost(p,x),x)
end

function trajectory_cost(params::NamedTuple,    # params 
    X::Vector{Vector{Float64}},                 # state trajectory 
    U::Vector{Vector{Float64}})                 # control trajectory 
    
    N = params.N

    J = 0.0
    for i = 1:N-1
    J += stage_cost(params, X[i], U[i], i)
    end
    J += term_cost(params, X[N])
    return J
end
# Out:
# trajectory_cost (generic function with 1 method)

# %%
function backward_pass(params::NamedTuple,          # useful params 
                       X::Vector{Vector{Float64}},  # state trajectory 
                       U::Vector{Vector{Float64}})  # control trajectory 
    # compute the iLQR backwards pass given a dynamically feasible trajectory X and U
    # return d, K, ΔJ  
    
    # outputs:
    #     d  - Vector{Vector} feedforward control  
    #     K  - Vector{Matrix} feedback gains 
    #     ΔJ - Float64        expected decrease in cost 
    
    nx, nu, N = params.nx, params.nu, params.N 

    # vectors of vectors/matrices for recursion 
    P = [zeros(nx,nx) for i = 1:N]   # cost to go quadratic term
    p = [zeros(nx)    for i = 1:N]   # cost to go linear term
    d = [zeros(nu)    for i = 1:N-1] # feedforward control
    K = [zeros(nu,nx) for i = 1:N-1] # feedback gain
    
    Qf = params.Qf
    Q = params.Q
    R = params.R
    Xref = params.Xref
    Uref = params.Uref
    
    ΔJ = 0.0
    p[N] .= Qf*(X[N]-Xref[N])
    P[N] .= Qf

    for k = N-1:-1:1
        
        #Calculate derivatives
        q = Q*(X[k]-Xref[k])
        r = R*(U[k]-Uref[k])
    
        A = FD.jacobian(dx->discrete_dynamics(params, dx, U[k], k),X[k])
        B = FD.jacobian(du->discrete_dynamics(params, X[k], du, k),U[k])
        
        gx = q + A'*p[k+1]
        gu = r + B'*p[k+1]
    
        #iLQR (Gauss-Newton) version
        Gxx = Q + A'*P[k+1]*A
        Guu = R + B'*P[k+1]*B
        Gxu = A'*P[k+1]*B
        Gux = B'*P[k+1]*A
        
        # Regularization
        β = 0.1
        while !isposdef(Symmetric([Gxx Gxu; Gux Guu]))
            Gxx += A'*β*I*A
            Guu += B'*β*I*B
            Gxu += A'*β*I*B
            Gux += B'*β*I*A
            β = 2*β
        end
        
        # Calculate d and K
        d[k] = Guu\gu
        K[k] .= Guu\Gux
    
        # Update p and P
        p[k] .= gx - K[k]'*gu + K[k]'*Guu*d[k] - Gxu*d[k]
        P[k] .= Gxx + K[k]'*Guu*K[k] - Gxu*K[k] - K[k]'*Gux
    
        ΔJ += gu'*d[k]
    end

    return d, K, ΔJ
end

function forward_pass(params::NamedTuple,           # useful params 
                      X::Vector{Vector{Float64}},   # state trajectory 
                      U::Vector{Vector{Float64}},   # control trajectory 
                      d::Vector{Vector{Float64}},   # feedforward controls 
                      K::Vector{Matrix{Float64}};   # feedback gains
                      max_linesearch_iters = 20)    # max iters on linesearch 
    # forward pass in iLQR with linesearch 
    # use a line search where the trajectory cost simply has to decrease (no Armijo)
    
    # outputs:
    #     Xn::Vector{Vector}  updated state trajectory  
    #     Un::Vector{Vector}  updated control trajectory 
    #     J::Float64          updated cost  
    #     α::Float64.         step length 

    nx, nu, N = params.nx, params.nu, params.N 
    
    Xn = [zeros(nx) for i = 1:N]      # new state history 
    Un = [zeros(nu) for i = 1:N-1]    # new control history 
    
    # initial condition 
    Xn[1] = 1*X[1]
    
    # initial step length 
    α = 1.0
    
    # forward pass 
    J = trajectory_cost(params, X, U)
    for i = 1:max_linesearch_iters
        for k = 1:N-1
            Un[k] = U[k] - α*d[k] - K[k]*(Xn[k]-X[k])
            Xn[k+1] .= discrete_dynamics(params, Xn[k], Un[k], k)
        end
        Jn = trajectory_cost(params, Xn, Un)
        α = 0.5*α

        if Jn < J
            return Xn, Un, Jn, α
        end
    end

    error("forward pass failed")
end
# Out:
# forward_pass (generic function with 1 method)

# %%
function iLQR(params::NamedTuple,         # useful params for costs/dynamics/indexing 
              x0::Vector,                 # initial condition 
              U::Vector{Vector{Float64}}; # initial controls 
              atol=1e-3,                  # convergence criteria: ΔJ < atol 
              max_iters = 250,            # max iLQR iterations 
              verbose = true)             # print logging
    
    # iLQR solver given an initial condition x0, initial controls U, and a 
    # dynamics function described by `discrete_dynamics`
    
    # return (X, U, K) where 
    # outputs:
    #     X::Vector{Vector} - state trajectory 
    #     U::Vector{Vector} - control trajectory 
    #     K::Vector{Matrix} - feedback gains K 

    # first check the sizes of everything
    @assert length(U) == params.N-1
    @assert length(U[1]) == params.nu
    @assert length(x0) == params.nx 

    nx, nu, N = params.nx, params.nu, params.N

    # initial rollout
    X = [zeros(nx) for i = 1:N]
    X[1] .= 1*x0
    for k = 1:N-1
        X[k+1] .= discrete_dynamics(params, X[k], U[k], k)
    end

    for ilqr_iter = 1:max_iters

        d, K, ΔJ = backward_pass(params, X, U)
        X, U, J, α = forward_pass(params, X, U, d, K)
        
        # termination criteria 
        if ΔJ < atol 
            if verbose 
                @info "iLQR converged"
            end
            return X, U, K 
        end
        
        # ---------------logging -------------------
        if verbose
            dmax = maximum(norm.(d))
            if rem(ilqr_iter-1,10)==0
                @printf "iter     J           ΔJ        |d|         α         \n"
                @printf "-------------------------------------------------\n"
            end
            @printf("%3d   %10.3e  %9.2e  %9.2e  %6.4f    \n",
              ilqr_iter, J, ΔJ, dmax, α)
        end
        
    end
    error("iLQR failed")
end
# Out:
# iLQR (generic function with 1 method)

# %%
function create_reference(params, N, dt)
    # create reference trajectory for tiltrotor 
    M = floor(Int, 5/dt)
    Xref = [[0;0;2*i/M;0;0;2/5;zeros(8)] for i = 1:N]
    uhover = ((9.81*params.mass/2)/params.kf)*ones(4)
    uhover[3] = 0.0
    uhover[4] = 0.0
    Uref = [uhover for i = 1:(N-1)]

    v_cruise = sqrt(2*params.mass*9.81/(params.ρ*params.S_wing*C_l(0)))

    for i = M+1:N-1
        Xref[i] = [v_cruise*(i-M)*dt;0;2;v_cruise;0;0;zeros(6);pi/2;pi/2]
    end

    Xref[N] = Xref[N-1]
    Xref[N][1] = v_cruise*(N-M)*dt
    return Xref, Uref
end
# Out:
# create_reference (generic function with 1 method)

# %%
function solve_tiltrotor_trajectory(;verbose = true)
    
    # problem size 
    nx = 14
    nu = 4
    dt = 0.05 
    tf = 6
    t_vec = 0:dt:tf
    N = length(t_vec)

    # dynamics parameters (these are estimated)
    model = (
        mass=0.5,
        J=Diagonal([0.0023, 0.0023, 0.004]),
        gravity=[0,0,-9.81],
        L=0.1750,
        kf=1.0,
        km=0.0245,
        kδ=1.0,
        S_wing=0.1,
        ρ = 1.225,
        dt = dt
        )

    # create reference trajectory 
    Xref, Uref = create_reference(model, N, dt)

    # tracking cost function
    Q = 1*diagm([1*ones(3);.1*ones(3);1*ones(3);.1*ones(3);.1*ones(2)])
    R = .1*diagm(ones(nu))
    Qf = 10*Q 

    # the params needed by iLQR 
    params = (
        N = N, 
        nx = nx, 
        nu = nu, 
        Xref = Xref, 
        Uref = Uref, 
        Q = Q, 
        R = R, 
        Qf = Qf, 
        model = model
    )

    # initial condition 
    x0 = 1*Xref[1]
    
    # initial guess controls 
    U = [(uref + .0001*randn(nu)) for uref in Uref]
    
    # solve with iLQR
    X, U, K = iLQR(params,x0,U;atol=1e-4,max_iters = 250,verbose = verbose)
    
    return X, U, K, t_vec, params
end
# Out:
# solve_tiltrotor_trajectory (generic function with 1 method)

# %%
Xilqr, Uilqr, Kilqr, t_vec, params =  solve_tiltrotor_trajectory(verbose = true)

# ---------------plotting------------------
Xm = hcat(Xilqr...)
Um = hcat(Uilqr...)
display(plot(t_vec, Xm[1:3,:]', xlabel = "time (s)", ylabel = "position (m)",
                                title = "Position", label = ["r_x" "r_y" "r_z"]))
display(plot(t_vec, Xm[4:6,:]', xlabel = "time (s)", ylabel = "velocity (m/s)",
                                title = "Velocity", label = ["v_x" "v_y" "v_z"]))
display(plot(t_vec, Xm[7:9,:]', xlabel = "time (s)", ylabel = "MRP",
                                title = "Attitude (MRP)", label = ["p_x" "p_y" "p_z"]))
display(plot(t_vec, Xm[10:12,:]', xlabel = "time (s)", ylabel = "angular velocity (rad/s)",
                                title = "Angular Velocity", label = ["ω_x" "ω_y" "ω_z"]))
display(plot(t_vec[1:end-1], Um', xlabel = "time (s)", ylabel = "rotor speeds (rad/s)",
                                title = "Controls", label = ["u_1" "u_2" "u_3" "u_4"]))
# Out:
# iter     J           ΔJ        |d|         α
# -------------------------------------------------
#   1    4.895e+02   3.61e+03   4.35e+01  0.2500
#   2    3.918e+01   9.17e+02   2.32e+01  0.5000
#   3    2.762e+01   2.33e+01   2.51e+00  0.5000
#   4    2.701e+01   1.23e+00   6.60e-01  0.5000
#   5    2.698e+01   1.30e-01   1.47e-01  0.5000
#   6    2.696e+01   1.22e-01   1.91e-01  0.5000
#   7    2.694e+01   1.08e-01   1.67e-01  0.2500
#   8    2.693e+01   1.27e-02   4.45e-02  0.5000
#   9    2.693e+01   6.84e-03   3.16e-02  0.5000
#  10    2.692e+01   5.40e-03   4.05e-02  0.5000
# iter     J           ΔJ        |d|         α
# -------------------------------------------------
#  11    2.692e+01   4.99e-03   3.29e-02  0.5000
#  12    2.692e+01   5.75e-03   4.23e-02  0.5000
#  13    2.692e+01   7.13e-03   3.81e-02  0.2500
#  14    2.692e+01   6.48e-04   5.85e-03  0.5000
#  15    2.692e+01   7.56e-04   8.32e-03  0.5000
#  16    2.692e+01   9.85e-04   6.17e-03  0.5000
#  17    2.692e+01   1.14e-03   1.17e-02  0.5000
#  18    2.692e+01   1.21e-03   8.05e-03  0.5000
#  19    2.692e+01   1.25e-03   1.21e-02  0.5000
#  20    2.692e+01   1.32e-03   9.91e-03  0.5000
# iter     J           ΔJ        |d|         α
# -------------------------------------------------
#  21    2.692e+01   1.37e-03   1.23e-02  0.5000
#  22    2.692e+01   1.45e-03   1.12e-02  0.5000
#  23    2.692e+01   1.52e-03   1.24e-02  0.5000
#  24    2.692e+01   1.62e-03   1.18e-02  0.5000
#  25    2.692e+01   1.72e-03   1.26e-02  0.5000
#  26    2.692e+01   1.87e-03   1.28e-02  0.5000
#  27    2.692e+01   2.03e-03   1.47e-02  0.2500
# ┌ Info: iLQR converged
# └ @ Main /home/hariharan/tiltrotor_control/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W5sZmlsZQ==.jl:39

# %% [markdown]
# ## Tracking solution with TVLQR
#
# Here we take a trajectory from a trajectory optimization solver, and track it with TVLQR to account for some model mismatch.

# %%
# real model parameters for dynamics 
model_real = (
        mass=0.52,
        J=Diagonal([0.0025, 0.002, 0.0045]),
        gravity=[0,0,-9.81],
        L=0.1550,
        kf=1.01,
        km=0.0365,
        kδ=0.99,
        S_wing=0.1,
        ρ = 1.225,
        dt = 0.05,
        )

# simulate closed loop system 
nx, nu, N = params.nx, params.nu, params.N
Xsim = [zeros(nx) for i = 1:N]
Usim = [zeros(nx) for i = 1:(N-1)]

# initial condition 
Xsim[1] = 1*Xilqr[1]

# simulate with closed loop control 
for i = 1:(N-1) 
    Usim[i] = -Kilqr[i]*(Xsim[i]-Xilqr[i]) + Uilqr[i]
    Xsim[i+1] = rk4(model_real, tiltrotor_dynamics_mrp, Xsim[i], Usim[i], model_real.dt)
end

# -----------------plotting---------------------
Xm = hcat(Xsim...)
Um = hcat(Usim...)
Xilqrm = hcat(Xilqr...)
Uilqrm = hcat(Uilqr...)
plot(t_vec,Xilqrm[1:3,:]',ls=:dash, label = "",lc = [:red :green :blue])
display(plot!(t_vec,Xm[1:3,:]',title = "Position (-- is iLQR reference)",
                xlabel = "time(s)", ylabel = "position (m)",
                label = ["r_x" "r_y" "r_z"],lc = [:red :green :blue]))

plot(t_vec,Xilqrm[7:9,:]',ls=:dash, label = "",lc = [:red :green :blue])
display(plot!(t_vec,Xm[7:9,:]',title = "Attitude (-- is iLQR reference)",
                xlabel = "time(s)", ylabel = "Attitude (MRP)",
                label = ["p_x" "p_y" "p_z"],lc = [:red :green :blue]))

# %%
display(animate_tiltrotor_mrp(Xsim, model_real.dt))
# Out:
# ┌ Info: Listening on: 127.0.0.1:8700, thread id: 1
# └ @ HTTP.Servers /home/hariharan/.julia/packages/HTTP/MIUdD/src/Servers.jl:382
# ┌ Info: MeshCat server started. You can open the visualizer by visiting the following URL in your browser:
# │ http://127.0.0.1:8700
# └ @ MeshCat /home/hariharan/.julia/packages/MeshCat/0RCA3/src/visualizer.jl:64
# MeshCat.DisplayedVisualizer(MeshCat.CoreVisualizer(MeshCat.SceneTrees.SceneNode(nothing, nothing, Dict{String, Vector{UInt8}}(), UInt8[0x83, 0xa7, 0x6f, 0x70, 0x74, 0x69, 0x6f, 0x6e, 0x73, 0x82  …  0x5f, 0x61, 0x6e, 0x69, 0x6d, 0x61, 0x74, 0x69, 0x6f, 0x6e], Dict{String, MeshCat.SceneTrees.SceneNode}("meshcat" => MeshCat.SceneTrees.SceneNode(nothing, nothing, Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}("world" => MeshCat.SceneTrees.SceneNode(nothing, nothing, Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}("left_eng" => MeshCat.SceneTrees.SceneNode(nothing, UInt8[0x83, 0xa6, 0x6d, 0x61, 0x74, 0x72, 0x69, 0x78, 0xc7, 0x40  …  0x64, 0x2f, 0x6c, 0x65, 0x66, 0x74, 0x5f, 0x65, 0x6e, 0x67], Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}("after_left_prop_joint" => MeshCat.SceneTrees.SceneNode(nothing, UInt8[0x83, 0xa6, 0x6d, 0x61, 0x74, 0x72, 0x69, 0x78, 0xc7, 0x40  …  0x70, 0x72, 0x6f, 0x70, 0x5f, 0x6a, 0x6f, 0x69, 0x6e, 0x74], Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}("geometry_7" => MeshCat.SceneTrees.SceneNode(UInt8[0x83, 0xa6, 0x6f, 0x62, 0x6a, 0x65, 0x63, 0x74, 0x84, 0xaa  …  0x67, 0x65, 0x6f, 0x6d, 0x65, 0x74, 0x72, 0x79, 0x5f, 0x37], UInt8[0x83, 0xa6, 0x6d, 0x61, 0x74, 0x72, 0x69, 0x78, 0xc7, 0x40  …  0x67, 0x65, 0x6f, 0x6d, 0x65, 0x74, 0x72, 0x79, 0x5f, 0x37], Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}()))), "after_left_eng_joint" => MeshCat.SceneTrees.SceneNode(nothing, UInt8[0x83, 0xa6, 0x6d, 0x61, 0x74, 0x72, 0x69, 0x78, 0xc7, 0x40  …  0x5f, 0x65, 0x6e, 0x67, 0x5f, 0x6a, 0x6f, 0x69, 0x6e, 0x74], Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}("geometry_5" => MeshCat.SceneTrees.SceneNode(UInt8[0x83, 0xa6, 0x6f, 0x62, 0x6a, 0x65, 0x63, 0x74, 0x84, 0xaa  …  0x67, 0x65, 0x6f, 0x6d, 0x65, 0x74, 0x72, 0x79, 0x5f, 0x35], UInt8[0x83, 0xa6, 0x6d, 0x61, 0x74, 0x72, 0x69, 0x78, 0xc7, 0x40  …  0x67, 0x65, 0x6f, 0x6d, 0x65, 0x74, 0x72, 0x79, 0x5f, 0x35], Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}()))))), "base_link" => MeshCat.SceneTrees.SceneNode(nothing, UInt8[0x83, 0xa6, 0x6d, 0x61, 0x74, 0x72, 0x69, 0x78, 0xc7, 0x40  …  0x2f, 0x62, 0x61, 0x73, 0x65, 0x5f, 0x6c, 0x69, 0x6e, 0x6b], Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}("geometry_1" => MeshCat.SceneTrees.SceneNode(UInt8[0x83, 0xa6, 0x6f, 0x62, 0x6a, 0x65, 0x63, 0x74, 0x84, 0xaa  …  0x67, 0x65, 0x6f, 0x6d, 0x65, 0x74, 0x72, 0x79, 0x5f, 0x31], UInt8[0x83, 0xa6, 0x6d, 0x61, 0x74, 0x72, 0x69, 0x78, 0xc7, 0x40  …  0x67, 0x65, 0x6f, 0x6d, 0x65, 0x74, 0x72, 0x79, 0x5f, 0x31], Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}()))), "after_tail_joint" => MeshCat.SceneTrees.SceneNode(nothing, UInt8[0x83, 0xa6, 0x6d, 0x61, 0x74, 0x72, 0x69, 0x78, 0xc7, 0x40  …  0x74, 0x61, 0x69, 0x6c, 0x5f, 0x6a, 0x6f, 0x69, 0x6e, 0x74], Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}("geometry_2" => MeshCat.SceneTrees.SceneNode(UInt8[0x83, 0xa6, 0x6f, 0x62, 0x6a, 0x65, 0x63, 0x74, 0x84, 0xaa  …  0x67, 0x65, 0x6f, 0x6d, 0x65, 0x74, 0x72, 0x79, 0x5f, 0x32], UInt8[0x83, 0xa6, 0x6d, 0x61, 0x74, 0x72, 0x69, 0x78, 0xc7, 0x40  …  0x67, 0x65, 0x6f, 0x6d, 0x65, 0x74, 0x72, 0x79, 0x5f, 0x32], Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}()))), "after_right_wing_joint" => MeshCat.SceneTrees.SceneNode(nothing, UInt8[0x83, 0xa6, 0x6d, 0x61, 0x74, 0x72, 0x69, 0x78, 0xc7, 0x40  …  0x77, 0x69, 0x6e, 0x67, 0x5f, 0x6a, 0x6f, 0x69, 0x6e, 0x74], Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}("geometry_4" => MeshCat.SceneTrees.SceneNode(UInt8[0x83, 0xa6, 0x6f, 0x62, 0x6a, 0x65, 0x63, 0x74, 0x84, 0xaa  …  0x67, 0x65, 0x6f, 0x6d, 0x65, 0x74, 0x72, 0x79, 0x5f, 0x34], UInt8[0x83, 0xa6, 0x6d, ...
